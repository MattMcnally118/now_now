# %% [markdown]
# Imports

# %%
import requests
import math
import time
import pandas as pd
import numpy as np

from datetime import date
from dateutil.relativedelta import relativedelta

# %% [markdown]
# Universal Parameters

# %%
PLACE_ID = 6986  # South Africa

# The last 5 years of data
today = date.today()
D2 = today.isoformat()
D1 = (today - relativedelta(years=5)).isoformat()

# %% [markdown]
# API fetch function:

# %%
def fetch_inat_observations(
    taxon_id: int,
    place_id: int = PLACE_ID,
    d1: str | None = None,
    d2: str | None = None,
    verifiable: bool = True,
    per_page: int = 200,
    max_records: int = 50000,
    sleep_sec: float = 0.2,
) -> pd.DataFrame:
    # Defaults to your rolling 5-year window if not provided
    if d1 is None: d1 = D1
    if d2 is None: d2 = D2
    per_page = min(max(1, per_page), 200)

    base = "https://api.inaturalist.org/v1/observations"
    common_params = {
        "taxon_id": taxon_id,
        "place_id": place_id,
        "verifiable": "true" if verifiable else "false",
        "d1": d1, "d2": d2,
    }

    # Probe total
    probe = requests.get(base, params={**common_params, "page": 1, "per_page": 1}, timeout=30)
    probe.raise_for_status()
    total = probe.json().get("total_results", 0)
    print(f"[iNat] taxon_id={taxon_id}, place_id={place_id}, {d1}→{d2} | total verifiable: {total}")
    if total == 0:
        return pd.DataFrame()

    # Paginate
    rows = []
    pages = min(math.ceil(total / per_page), math.ceil(max_records / per_page))
    for page in range(1, pages + 1):
        r = requests.get(base, params={**common_params, "page": page, "per_page": per_page}, timeout=60)
        r.raise_for_status()
        rows.extend(r.json().get("results", []))
        if len(rows) >= max_records:
            break
        time.sleep(sleep_sec)

    raw_df = pd.json_normalize(rows)
    print(f"Fetched rows: {len(raw_df)}")
    return raw_df

# %% [markdown]
# Cleaning Function:

# %%
KEEP_COLS = [
    "taxon.id",
    "taxon.name",
    "taxon.preferred_common_name",
    "longitude",
    "latitude",
    "observed_on_details.date",
    "observed_on_details.hour",
    "place_ids",
]

def clean_inat_minimal(raw_df: pd.DataFrame) -> pd.DataFrame:
    """Keep only selected iNat columns; derive lon/lat from 'location' ('lat,lon')."""
    out = raw_df.copy()

    if "location" in out.columns:
        loc = out["location"].astype(str).str.split(",", n=1, expand=True)
        out["latitude"]  = pd.to_numeric(loc[0].str.strip(), errors="coerce")
        out["longitude"] = pd.to_numeric(loc[1].str.strip(), errors="coerce")
    else:
        out["latitude"]  = np.nan
        out["longitude"] = np.nan

    for c in KEEP_COLS:
        if c not in out.columns:
            out[c] = np.nan


    return out[KEEP_COLS].reset_index(drop=True)

# %% [markdown]
# Fetching data for each animal:

# %% [markdown]
# 1. Lion:

# %%
TAXON_ID = 41964
raw_df = fetch_inat_observations(TAXON_ID)

print(len(raw_df))
raw_df.head(2)
# Out:
# [iNat] taxon_id=41964, place_id=6986, 2020-10-15→2025-10-15 | total verifiable: 2495
# Fetched rows: 2495
# 2495
#   quality_grade           time_observed_at taxon_geoprivacy annotations  \
# 0      research  2025-10-13T09:44:22+02:00         obscured          []
# 1      research  2025-10-15T06:05:50+02:00         obscured          []
#
#                                    uuid         id  cached_votes_total  \
# 0  16396bac-715a-4fd8-a986-a03b03f73c9d  321007782                   0
# 1  e02f0ee1-e1ec-4a21-9cec-d75951c0aa9d  321001872                   0
#
#    identifications_most_agree  species_guess  identifications_most_disagree  \
# 0                        True           Lion                          False
# 1                        True  Southern Lion                          False
#
#    ... user.journal_posts_count  user.activity_count  user.species_count  \
# 0  ...                        0                  437                 370
# 1  ...                        0                 8277                1643
#
#    user.annotated_observations_count user.universal_search_rank user.roles  \
# 0                                0.0                        436         []
# 1                                0.0                       7106         []
#
#                                        user.icon_url  \
# 0  https://static.inaturalist.org/attachments/use...
# 1                                               None
#
#   user.preferences.prefers_project_addition_by  \
# 0                                          NaN
# 1                                          NaN
#
#    user.preferences.prefers_community_taxa  \
# 0                                      NaN
# 1                                      NaN
#
#   user.preferences.prefers_observation_fields_by
# 0                                            NaN
# 1                                            NaN
#
# [2 rows x 156 columns]

# %%
lion_df = clean_inat_minimal(raw_df)
print(lion_df.shape)
lion_df.head()
# Out:
# (2495, 8)
#    taxon.id                 taxon.name taxon.preferred_common_name  longitude  \
# 0     41964               Panthera leo                        Lion  32.200070
# 1    557401  Panthera leo melanochaita               Southern Lion  31.966613
# 2    557401  Panthera leo melanochaita               Southern Lion  31.900091
# 3    557401  Panthera leo melanochaita               Southern Lion  31.579412
# 4    557401  Panthera leo melanochaita               Southern Lion  31.908049
#
#     latitude observed_on_details.date  observed_on_details.hour  \
# 0 -27.734227               2025-10-13                         9
# 1 -24.480334               2025-10-15                         6
# 2 -24.572784               2025-10-15                         5
# 3 -24.875755               2025-08-15                         7
# 4 -25.278137               2025-08-07                        17
#
#                                            place_ids
# 0  [6986, 13313, 48462, 59647, 91708, 97392, 1081...
# 1  [6986, 7478, 48525, 57957, 59647, 69020, 91708...
# 2  [6986, 7478, 48525, 57957, 59647, 69020, 91708...
# 3  [6986, 7478, 48525, 57957, 59647, 91708, 97392...
# 4  [6986, 7478, 48532, 57957, 59647, 69020, 91708...

# %% [markdown]
# 2. Warthog:

# %%
TAXON_ID = 42122
raw_df = fetch_inat_observations(TAXON_ID)

print(len(raw_df))
raw_df.head(2)
# Out:
# [iNat] taxon_id=42122, place_id=6986, 2020-10-15→2025-10-15 | total verifiable: 2661
# Fetched rows: 2661
# 2661
#   quality_grade           time_observed_at taxon_geoprivacy annotations  \
# 0      research  2025-10-08T11:36:38+02:00             open          []
# 1      research  2025-10-08T09:18:15+02:00             open          []
#
#                                    uuid         id  cached_votes_total  \
# 0  f45150d2-9411-4b44-a967-41e4fa952c9a  320891360                   0
# 1  53723da7-76b4-4dfa-8be0-8716c9992158  320890370                   0
#
#    identifications_most_agree     species_guess  \
# 0                        True  Southern Warthog
# 1                        True  Southern Warthog
#
#    identifications_most_disagree  ... user.icon_url  \
# 0                          False  ...          None
# 1                          False  ...          None
#
#    taxon.establishment_means.id  taxon.establishment_means.place_id  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
#
#    taxon.establishment_means.user_id  \
# 0                                NaN
# 1                                NaN
#
#   taxon.establishment_means.occurrence_status_level  \
# 0                                               NaN
# 1                                               NaN
#
#   taxon.establishment_means.establishment_means  \
# 0                                           NaN
# 1                                           NaN
#
#   taxon.preferred_establishment_means  \
# 0                                 NaN
# 1                                 NaN
#
#   user.preferences.prefers_project_addition_by  \
# 0                                          NaN
# 1                                          NaN
#
#    user.preferences.prefers_observation_fields_by  \
# 0                                             NaN
# 1                                             NaN
#
#   user.preferences.prefers_community_taxa
# 0                                     NaN
# 1                                     NaN
#
# [2 rows x 146 columns]

# %%
warthog_df = clean_inat_minimal(raw_df)
print(warthog_df.shape)
warthog_df.head()
# Out:
# (2661, 8)
#    taxon.id                          taxon.name taxon.preferred_common_name  \
# 0    531646  Phacochoerus africanus sundevallii            Southern Warthog
# 1    531646  Phacochoerus africanus sundevallii            Southern Warthog
# 2    531646  Phacochoerus africanus sundevallii            Southern Warthog
# 3    531646  Phacochoerus africanus sundevallii            Southern Warthog
# 4    531646  Phacochoerus africanus sundevallii            Southern Warthog
#
#    longitude   latitude observed_on_details.date  observed_on_details.hour  \
# 0  25.770331 -33.446211               2025-10-08                        11
# 1  25.661428 -33.584344               2025-10-08                         9
# 2  31.686009 -24.392211               2025-10-14                        17
# 3  31.893530 -25.358438               2025-10-01                        10
# 4  31.827906 -28.230942               2025-10-04                        16
#
#                                            place_ids
# 0  [6986, 8872, 48322, 51115, 59647, 69022, 91708...
# 1  [6986, 8872, 48351, 51115, 59647, 91708, 97392...
# 2  [6986, 7478, 48525, 57957, 59647, 69020, 91708...
# 3  [6986, 7478, 48532, 57957, 59647, 69020, 91708...
# 4  [6986, 13313, 48440, 59647, 71275, 91708, 9739...

# %% [markdown]
# 3. Elephant:

# %%
TAXON_ID = 43694
raw_df = fetch_inat_observations(TAXON_ID)

print(len(raw_df))
raw_df.head(2)
# Out:
# [iNat] taxon_id=43694, place_id=6986, 2020-10-15→2025-10-15 | total verifiable: 4701
# Fetched rows: 4701
# 4701
#   quality_grade           time_observed_at taxon_geoprivacy annotations  \
# 0      research  2025-10-14T16:52:52+02:00         obscured          []
# 1      needs_id  2025-10-13T17:07:45+02:00         obscured          []
#
#                                    uuid         id  cached_votes_total  \
# 0  b16d45c2-2829-4f73-bd54-d3b8e05103ab  320885819                   0
# 1  dff7d5b3-ebff-4a83-acd1-1a23f4b48996  320658052                   0
#
#    identifications_most_agree             species_guess  \
# 0                        True  African Savanna Elephant
# 1                       False                      None
#
#    identifications_most_disagree  ... user.activity_count  user.species_count  \
# 0                          False  ...                 866                 397
# 1                          False  ...                 183                 165
#
#    user.annotated_observations_count  user.universal_search_rank user.roles  \
# 0                               92.0                         619         []
# 1                                0.0                         183         []
#
#                                        user.icon_url  \
# 0  https://static.inaturalist.org/attachments/use...
# 1                                               None
#
#   user.preferences.prefers_project_addition_by  \
# 0                                          NaN
# 1                                          NaN
#
#   user.preferences.prefers_observation_fields_by  \
# 0                                            NaN
# 1                                            NaN
#
#    user.preferences.prefers_community_taxa observation_sounds
# 0                                      NaN                NaN
# 1                                      NaN                NaN
#
# [2 rows x 156 columns]

# %%
elephant_df = clean_inat_minimal(raw_df)
print(elephant_df.shape)
elephant_df.head()
# Out:
# (4701, 8)
#    taxon.id          taxon.name taxon.preferred_common_name  longitude  \
# 0     43694  Loxodonta africana    African Savanna Elephant  31.553999
# 1     43694  Loxodonta africana    African Savanna Elephant  31.748145
# 2     43694  Loxodonta africana    African Savanna Elephant  31.631425
# 3     43694  Loxodonta africana    African Savanna Elephant  31.855951
# 4     43694  Loxodonta africana    African Savanna Elephant  31.964403
#
#     latitude observed_on_details.date  observed_on_details.hour  \
# 0 -24.417992               2025-10-14                        16
# 1 -23.909330               2025-10-13                        17
# 2 -25.153200               2025-10-05                        10
# 3 -28.259990               2025-10-04                        19
# 4 -28.360771               2025-10-04                        19
#
#                                            place_ids
# 0  [6986, 7478, 48525, 57957, 59647, 69020, 91708...
# 1  [6986, 9074, 48488, 53299, 59647, 69020, 91708...
# 2  [6986, 7478, 48532, 57957, 59647, 69020, 91708...
# 3  [6986, 13313, 59647, 71275, 91708, 97392, 1081...
# 4  [6986, 13313, 59647, 71275, 91708, 97392, 1081...

# %% [markdown]
# 4. Cheetah:

# %%
TAXON_ID = 41955
raw_df = fetch_inat_observations(TAXON_ID)

print(len(raw_df))
raw_df.head(2)
# Out:
# [iNat] taxon_id=41955, place_id=6986, 2020-10-15→2025-10-15 | total verifiable: 708
# Fetched rows: 708
# 708
#   quality_grade           time_observed_at taxon_geoprivacy annotations  \
# 0      research  2025-10-06T07:36:48+02:00         obscured          []
# 1      research                       None         obscured          []
#
#                                    uuid         id  cached_votes_total  \
# 0  5c96b695-be0e-4c41-b0a7-895fc2a482cb  320862049                   0
# 1  8958485d-ecb9-4b22-ac85-314f34a641a3  320127038                   0
#
#    identifications_most_agree                         species_guess  \
# 0                        True  Southern and Eastern African Cheetah
# 1                        True                      Southern Cheetah
#
#    identifications_most_disagree  ... taxon.conservation_status.iucn  \
# 0                          False  ...                            NaN
# 1                          False  ...                            NaN
#
#    taxon.establishment_means.id  taxon.establishment_means.place_id  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
#
#    taxon.establishment_means.user_id  \
# 0                                NaN
# 1                                NaN
#
#   taxon.establishment_means.occurrence_status_level  \
# 0                                               NaN
# 1                                               NaN
#
#   taxon.establishment_means.establishment_means  \
# 0                                           NaN
# 1                                           NaN
#
#   taxon.preferred_establishment_means  \
# 0                                 NaN
# 1                                 NaN
#
#   user.preferences.prefers_project_addition_by  \
# 0                                          NaN
# 1                                          NaN
#
#    user.preferences.prefers_community_taxa  \
# 0                                      NaN
# 1                                      NaN
#
#   user.preferences.prefers_observation_fields_by
# 0                                            NaN
# 1                                            NaN
#
# [2 rows x 156 columns]

# %%
cheetah_df = clean_inat_minimal(raw_df)
print(cheetah_df.shape)
cheetah_df.head()
# Out:
# (708, 8)
#    taxon.id                taxon.name           taxon.preferred_common_name  \
# 0    606958  Acinonyx jubatus jubatus  Southern and Eastern African Cheetah
# 1    606958  Acinonyx jubatus jubatus  Southern and Eastern African Cheetah
# 2    606958  Acinonyx jubatus jubatus  Southern and Eastern African Cheetah
# 3    606958  Acinonyx jubatus jubatus  Southern and Eastern African Cheetah
# 4    606958  Acinonyx jubatus jubatus  Southern and Eastern African Cheetah
#
#    longitude   latitude observed_on_details.date  observed_on_details.hour  \
# 0  32.107006 -27.834913               2025-10-06                         7
# 1  25.401620 -32.150473               2025-10-05                         0
# 2  30.899824 -23.849435               2025-09-10                         8
# 3  31.572864 -23.834812               2024-04-01                         8
# 4  31.574401 -25.395065               2025-10-03                         9
#
#                                            place_ids
# 0  [6986, 13313, 48462, 59647, 91708, 97392, 1081...
# 1  [6986, 8872, 48332, 59647, 91708, 97392, 10810...
# 2  [6986, 9074, 48488, 53299, 59647, 91708, 97392...
# 3  [6986, 9074, 48488, 53299, 59647, 69020, 91708...
# 4  [6986, 7478, 48532, 57957, 59647, 69020, 91708...

# %% [markdown]
# 5. Giraffe:

# %%
TAXON_ID = 1510571
raw_df = fetch_inat_observations(TAXON_ID)

print(len(raw_df))
raw_df.head(2)
# Out:
# [iNat] taxon_id=1510571, place_id=6986, 2020-10-15→2025-10-15 | total verifiable: 3860
# Fetched rows: 3860
# 3860
#   quality_grade           time_observed_at taxon_geoprivacy annotations  \
# 0      research  2025-10-13T08:40:11+02:00             open          []
# 1      research  2025-10-14T15:51:57+02:00             open          []
#
#                                    uuid         id  cached_votes_total  \
# 0  b64e4332-0d51-46a4-b047-9b859f71b44b  320993365                   0
# 1  242101d5-b5e7-4f58-8d8d-9160e2319661  320885317                   0
#
#    identifications_most_agree          species_guess  \
# 0                        True  South African Giraffe
# 1                        True  South African Giraffe
#
#    identifications_most_disagree  ...  \
# 0                          False  ...
# 1                          False  ...
#
#                                        user.icon_url  \
# 0  https://static.inaturalist.org/attachments/use...
# 1  https://static.inaturalist.org/attachments/use...
#
#    taxon.establishment_means.id  taxon.establishment_means.place_id  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
#
#    taxon.establishment_means.user_id  \
# 0                                NaN
# 1                                NaN
#
#   taxon.establishment_means.occurrence_status_level  \
# 0                                               NaN
# 1                                               NaN
#
#   taxon.establishment_means.establishment_means  \
# 0                                           NaN
# 1                                           NaN
#
#   taxon.preferred_establishment_means  \
# 0                                 NaN
# 1                                 NaN
#
#   user.preferences.prefers_project_addition_by  \
# 0                                          NaN
# 1                                          NaN
#
#    user.preferences.prefers_observation_fields_by  \
# 0                                             NaN
# 1                                             NaN
#
#   user.preferences.prefers_community_taxa
# 0                                     NaN
# 1                                     NaN
#
# [2 rows x 146 columns]

# %%
giraffe_df = clean_inat_minimal(raw_df)
print(giraffe_df.shape)
giraffe_df.head()
# Out:
# (3860, 8)
#    taxon.id               taxon.name taxon.preferred_common_name  longitude  \
# 0   1510582  Giraffa giraffa giraffa       South African Giraffe  31.436620
# 1   1510582  Giraffa giraffa giraffa       South African Giraffe  31.483228
# 2   1510571          Giraffa giraffa            Southern Giraffe  22.147994
# 3   1510571          Giraffa giraffa            Southern Giraffe  31.630257
# 4   1510582  Giraffa giraffa giraffa       South African Giraffe  31.213092
#
#     latitude observed_on_details.date  observed_on_details.hour  \
# 0 -25.402870               2025-10-13                         8
# 1 -24.437263               2025-10-14                        15
# 2 -34.025250               2025-10-04                        13
# 3 -23.822058               2025-10-13                        17
# 4 -25.172888               2025-10-05                        15
#
#                                            place_ids
# 0  [6986, 7478, 48532, 57957, 59647, 69020, 91708...
# 1  [6986, 7478, 48525, 57957, 59647, 69020, 91708...
# 2  [6986, 6987, 48651, 59647, 91708, 97392, 10812...
# 3  [6986, 9074, 48488, 53299, 59647, 69020, 91708...
# 4  [6986, 7478, 48524, 57957, 59647, 69020, 91708...

# %% [markdown]
# 6. Hippo:

# %%
TAXON_ID = 42149
raw_df = fetch_inat_observations(TAXON_ID)

print(len(raw_df))
raw_df.head(2)
# Out:
# [iNat] taxon_id=42149, place_id=6986, 2020-10-15→2025-10-15 | total verifiable: 2445
# Fetched rows: 2445
# 2445
#   quality_grade           time_observed_at taxon_geoprivacy annotations  \
# 0      research  2025-09-04T03:49:00+02:00             None          []
# 1      research  2025-07-16T15:14:00+02:00             None          []
#
#                                    uuid         id  cached_votes_total  \
# 0  9b124681-65e2-47f7-97a5-6ebc4afa6f1a  320805742                   0
# 1  c2bfa6ba-19aa-43cd-a6fc-166a0b10edfd  320689614                   0
#
#    identifications_most_agree        species_guess  \
# 0                        True           Hipopótamo
# 1                        True  Common Hippopotamus
#
#    identifications_most_disagree  ... user.journal_posts_count  \
# 0                          False  ...                        0
# 1                          False  ...                        0
#
#    user.activity_count  user.species_count  user.annotated_observations_count  \
# 0                  114                  94                                0.0
# 1                  111                  72                                0.0
#
#   user.universal_search_rank user.roles user.icon_url  \
# 0                         99         []          None
# 1                         76         []          None
#
#   user.preferences.prefers_project_addition_by  \
# 0                                          NaN
# 1                                          NaN
#
#    user.preferences.prefers_community_taxa  \
# 0                                      NaN
# 1                                      NaN
#
#   user.preferences.prefers_observation_fields_by
# 0                                            NaN
# 1                                            NaN
#
# [2 rows x 155 columns]

# %%
hippo_df = clean_inat_minimal(raw_df)
print(hippo_df.shape)
hippo_df.head()
# Out:
# (2445, 8)
#    taxon.id              taxon.name taxon.preferred_common_name  longitude  \
# 0     42149  Hippopotamus amphibius         Common Hippopotamus  31.915379
# 1     42149  Hippopotamus amphibius         Common Hippopotamus  30.585290
# 2     42149  Hippopotamus amphibius         Common Hippopotamus  31.613224
# 3     42149  Hippopotamus amphibius         Common Hippopotamus  31.577587
# 4     42149  Hippopotamus amphibius         Common Hippopotamus  31.410626
#
#     latitude observed_on_details.date  observed_on_details.hour  \
# 0 -25.119860               2025-09-04                         3
# 1 -24.225022               2025-07-16                        15
# 2 -23.838688               2025-10-13                        16
# 3 -24.984697               2025-10-05                        12
# 4 -23.530782               2025-09-11                        16
#
#                                            place_ids
# 0  [6986, 7478, 48525, 57957, 59647, 69020, 91708...
# 1  [6986, 9074, 48477, 53299, 59647, 91708, 97392...
# 2  [6986, 9074, 48488, 53299, 59647, 69020, 91708...
# 3  [6986, 7478, 48532, 57957, 59647, 69020, 91708...
# 4  [6986, 9074, 48488, 53299, 59647, 69020, 91708...

# %% [markdown]
# 7. Plains Zebra:

# %%
TAXON_ID = 43335
raw_df = fetch_inat_observations(TAXON_ID)

print(len(raw_df))
raw_df.head(2)
# Out:
# [iNat] taxon_id=43335, place_id=6986, 2020-10-15→2025-10-15 | total verifiable: 4345
# Fetched rows: 4345
# 4345
#   quality_grade           time_observed_at taxon_geoprivacy annotations  \
# 0      needs_id  2025-10-13T16:08:47+02:00             None          []
# 1      research  2025-10-15T07:57:21+02:00             None          []
#
#                                    uuid         id  cached_votes_total  \
# 0  d1088e88-040e-42f5-9d01-829c96bf7d06  321005612                   0
# 1  dd1302bb-c36b-4167-a686-a33c13d5dde9  321001916                   0
#
#    identifications_most_agree species_guess  identifications_most_disagree  \
# 0                       False          None                          False
# 1                        True  Plains Zebra                          False
#
#    ... user.journal_posts_count  user.activity_count  user.species_count  \
# 0  ...                        0                  437                 370
# 1  ...                        0                 8277                1643
#
#    user.annotated_observations_count user.universal_search_rank user.roles  \
# 0                                0.0                        436         []
# 1                                0.0                       7106         []
#
#                                        user.icon_url  \
# 0  https://static.inaturalist.org/attachments/use...
# 1                                               None
#
#   user.preferences.prefers_project_addition_by  \
# 0                                          NaN
# 1                                          NaN
#
#    user.preferences.prefers_observation_fields_by  \
# 0                                             NaN
# 1                                             NaN
#
#   user.preferences.prefers_community_taxa
# 0                                     NaN
# 1                                     NaN
#
# [2 rows x 155 columns]

# %%
plains_zebra_df = clean_inat_minimal(raw_df)
print(plains_zebra_df.shape)
plains_zebra_df.head()
# Out:
# (4345, 8)
#    taxon.id    taxon.name taxon.preferred_common_name  longitude   latitude  \
# 0     43335  Equus quagga                Plains Zebra  32.338030 -27.832153
# 1     43335  Equus quagga                Plains Zebra  31.989558 -24.365383
# 2     43335  Equus quagga                Plains Zebra  31.454359 -24.975959
# 3     43335  Equus quagga                Plains Zebra  25.775011 -33.446122
# 4     43335  Equus quagga                Plains Zebra  31.699237 -24.391707
#
#   observed_on_details.date  observed_on_details.hour  \
# 0               2025-10-13                        16
# 1               2025-10-15                         7
# 2               2025-10-15                        10
# 3               2025-10-08                        11
# 4               2025-10-14                        17
#
#                                            place_ids
# 0  [6986, 13313, 48462, 59647, 91708, 97392, 1081...
# 1  [6986, 7478, 48525, 57957, 59647, 69020, 91708...
# 2  [6986, 7478, 48482, 57957, 59647, 91708, 97392...
# 3  [6986, 8872, 48322, 51115, 59647, 69022, 91708...
# 4  [6986, 7478, 48525, 57957, 59647, 69020, 91708...

# %% [markdown]
# 8. Mountain Zebra:

# %%
TAXON_ID = 43330
raw_df = fetch_inat_observations(TAXON_ID)

print(len(raw_df))
raw_df.head(2)
# Out:
# [iNat] taxon_id=43330, place_id=6986, 2020-10-15→2025-10-15 | total verifiable: 727
# Fetched rows: 727
# 727
#   quality_grade           time_observed_at taxon_geoprivacy annotations  \
# 0      research  2025-10-14T08:44:21+02:00             open          []
# 1      research  2025-10-13T10:52:00+02:00             open          []
#
#                                    uuid         id  cached_votes_total  \
# 0  fa216710-77ec-4ecc-a21d-bd9a9f7c8a7f  320986189                   1
# 1  09ae463c-1e26-4231-b699-7d5cbe13e68a  320674519                   0
#
#    identifications_most_agree        species_guess  \
# 0                        True       Mountain Zebra
# 1                        True  Cape Mountain Zebra
#
#    identifications_most_disagree  ... user.identifications_count  \
# 0                          False  ...                        131
# 1                          False  ...                          1
#
#    user.journal_posts_count  user.activity_count  user.species_count  \
# 0                         0                 2266                1175
# 1                         0                   36                  30
#
#   user.annotated_observations_count user.universal_search_rank user.roles  \
# 0                             355.0                       2135         []
# 1                               0.0                         35         []
#
#                                        user.icon_url  \
# 0  https://static.inaturalist.org/attachments/use...
# 1                                               None
#
#    user.preferences.prefers_project_addition_by  \
# 0                                           NaN
# 1                                           NaN
#
#   user.preferences.prefers_observation_fields_by
# 0                                            NaN
# 1                                            NaN
#
# [2 rows x 154 columns]

# %%
mountain_zebra_df = clean_inat_minimal(raw_df)
print(mountain_zebra_df.shape)
mountain_zebra_df.head()
# Out:
# (727, 8)
#    taxon.id         taxon.name taxon.preferred_common_name  longitude  \
# 0     43330        Equus zebra              Mountain Zebra  22.502972
# 1    132668  Equus zebra zebra         Cape Mountain Zebra  20.475947
# 2    132668  Equus zebra zebra         Cape Mountain Zebra  20.420317
# 3    132668  Equus zebra zebra         Cape Mountain Zebra  20.465855
# 4    132668  Equus zebra zebra         Cape Mountain Zebra  20.469004
#
#     latitude observed_on_details.date  observed_on_details.hour  \
# 0 -32.330037               2025-10-14                         8
# 1 -34.059425               2025-10-13                        10
# 2 -34.453768               2025-10-02                        10
# 3 -34.067412               2025-10-09                        16
# 4 -34.064380               2025-10-09                        16
#
#                                            place_ids
# 0  [6986, 6987, 48630, 59647, 69023, 91708, 97392...
# 1  [6986, 6987, 48663, 59647, 69028, 91708, 97392...
# 2  [6986, 6987, 48632, 59647, 69351, 91708, 97392...
# 3  [6986, 6987, 48663, 59647, 91708, 97392, 10813...
# 4  [6986, 6987, 48663, 59647, 91708, 97392, 10813...

# %% [markdown]
# Merge into one Animals df

# %%
animals_df = pd.concat( [lion_df, warthog_df, elephant_df, cheetah_df, giraffe_df, hippo_df, plains_zebra_df, mountain_zebra_df], ignore_index=True )
animals_df = animals_df.reindex(columns=KEEP_COLS)

# %% [markdown]
# Quick Look at the Animals df

# %%
# Quick peek before saving
print("Shape:", animals_df.shape)

# First few rows
display(animals_df.head(10))

# Counts by species (top 15)
if "taxon.preferred_common_name" in animals_df.columns:
    print("\nCounts by common name (top 15):")
    display(animals_df["taxon.preferred_common_name"].value_counts().head(15))

# Coordinate summary
if {"longitude","latitude"}.issubset(animals_df.columns):
    print("\nLongitude/Latitude summary:")
    display(animals_df[["longitude","latitude"]].describe())

# Date coverage
if "observed_on_details.date" in animals_df.columns:
    _dates = pd.to_datetime(animals_df["observed_on_details.date"], errors="coerce", utc=True)
    print("\nDate coverage:")
    print("  min:", _dates.min())
    print("  max:", _dates.max())
    print("  missing dates:", _dates.isna().sum())

# Quick missingness per column (percentage)
print("\nMissingness (% by column):")
display((animals_df.isna().mean()*100).round(1).sort_values(ascending=False))

# Very light duplicate check (same species, time (hour), and coords)
dupe_cols = ["taxon.id","observed_on_details.date","observed_on_details.hour","longitude","latitude"]
dupe_cols = [c for c in dupe_cols if c in animals_df.columns]
if dupe_cols:
    dupes = animals_df.duplicated(subset=dupe_cols).sum()
    print(f"\nPotential duplicate rows on {dupe_cols}: {dupes}")
# Out:
# Shape: (21942, 8)
#    taxon.id                 taxon.name taxon.preferred_common_name  longitude  \
# 0     41964               Panthera leo                        Lion  32.200070
# 1    557401  Panthera leo melanochaita               Southern Lion  31.966613
# 2    557401  Panthera leo melanochaita               Southern Lion  31.900091
# 3    557401  Panthera leo melanochaita               Southern Lion  31.579412
# 4    557401  Panthera leo melanochaita               Southern Lion  31.908049
# 5    557401  Panthera leo melanochaita               Southern Lion  31.598336
# 6    557401  Panthera leo melanochaita               Southern Lion  31.757075
# 7    557401  Panthera leo melanochaita               Southern Lion  31.740621
# 8    557401  Panthera leo melanochaita               Southern Lion  30.852415
# 9    557401  Panthera leo melanochaita               Southern Lion  30.930098
#
#     latitude observed_on_details.date  observed_on_details.hour  \
# 0 -27.734227               2025-10-13                         9
# 1 -24.480334               2025-10-15                         6
# 2 -24.572784               2025-10-15                         5
# 3 -24.875755               2025-08-15                         7
# 4 -25.278137               2025-08-07                        17
# 5 -25.169304               2025-10-07                         9
# 6 -24.859772               2025-10-06                        17
# 7 -24.972518               2025-10-06                         8
# 8 -23.989544               2025-09-14                        11
# 9 -23.970731               2025-09-14                        11
#
#                                            place_ids
# 0  [6986, 13313, 48462, 59647, 91708, 97392, 1081...
# 1  [6986, 7478, 48525, 57957, 59647, 69020, 91708...
# 2  [6986, 7478, 48525, 57957, 59647, 69020, 91708...
# 3  [6986, 7478, 48525, 57957, 59647, 91708, 97392...
# 4  [6986, 7478, 48532, 57957, 59647, 69020, 91708...
# 5  [6986, 7478, 48532, 57957, 59647, 69020, 91708...
# 6  [6986, 7478, 48525, 57957, 59647, 69020, 91708...
# 7  [6986, 7478, 57957, 59647, 69020, 91708, 97392...
# 8  [6986, 9074, 48488, 53299, 59647, 91708, 97392...
# 9  [6986, 9074, 48488, 53299, 59647, 91708, 97392...
# Counts by common name (top 15):
# taxon.preferred_common_name
# African Savanna Elephant                4701
# South African Giraffe                   3328
# Common Hippopotamus                     2445
# Southern Lion                           2424
# Southern Warthog                        2114
# Plains Zebra                            1968
# Chapman's Zebra                         1368
# Burchell's Zebra                        1009
# Southern and Eastern African Cheetah     687
# Cape Mountain Zebra                      647
# Common Warthog                           546
# Southern Giraffe                         522
# Lion                                      71
# Mountain Zebra                            62
# Cheetah                                   21
# Name: count, dtype: int64
# Longitude/Latitude summary:
#           longitude      latitude
# count  21942.000000  21942.000000
# mean      29.310522    -26.892062
# std        3.440205      3.410924
# min       17.948736    -34.748293
# 25%       27.105536    -28.302410
# 50%       31.304011    -25.279289
# 75%       31.719606    -24.573570
# max       32.924815    -22.039419
# Date coverage:
#   min: 2020-10-15 00:00:00+00:00
#   max: 2025-10-15 00:00:00+00:00
#   missing dates: 0
#
# Missingness (% by column):
# taxon.id                       0.0
# taxon.name                     0.0
# taxon.preferred_common_name    0.0
# longitude                      0.0
# latitude                       0.0
# observed_on_details.date       0.0
# observed_on_details.hour       0.0
# place_ids                      0.0
# dtype: float64
# Potential duplicate rows on ['taxon.id', 'observed_on_details.date', 'observed_on_details.hour', 'longitude', 'latitude']: 625

# %%
animals_df = animals_df.drop_duplicates(subset=dupe_cols)
print("Shape after dropping duplicates:", animals_df.shape)
# Out:
# Shape after dropping duplicates: (21317, 8)

# %%
animals_df
# Out:
#        taxon.id                 taxon.name taxon.preferred_common_name  \
# 0         41964               Panthera leo                        Lion
# 1        557401  Panthera leo melanochaita               Southern Lion
# 2        557401  Panthera leo melanochaita               Southern Lion
# 3        557401  Panthera leo melanochaita               Southern Lion
# 4        557401  Panthera leo melanochaita               Southern Lion
# ...         ...                        ...                         ...
# 21937    132668          Equus zebra zebra         Cape Mountain Zebra
# 21938    132668          Equus zebra zebra         Cape Mountain Zebra
# 21939    132668          Equus zebra zebra         Cape Mountain Zebra
# 21940    132668          Equus zebra zebra         Cape Mountain Zebra
# 21941    132668          Equus zebra zebra         Cape Mountain Zebra
#
#        longitude   latitude observed_on_details.date  \
# 0      32.200070 -27.734227               2025-10-13
# 1      31.966613 -24.480334               2025-10-15
# 2      31.900091 -24.572784               2025-10-15
# 3      31.579412 -24.875755               2025-08-15
# 4      31.908049 -25.278137               2025-08-07
# ...          ...        ...                      ...
# 21937  22.510217 -32.332507               2020-11-13
# 21938  22.505989 -32.331872               2020-11-13
# 21939  18.436840 -34.250275               2020-11-22
# 21940  22.355007 -32.263832               2020-10-31
# 21941  25.436188 -32.223106               2020-10-16
#
#        observed_on_details.hour  \
# 0                             9
# 1                             6
# 2                             5
# 3                             7
# 4                            17
# ...                         ...
# 21937                        18
# 21938                        16
# 21939                         9
# 21940                        14
# 21941                         5
#
#                                                place_ids
# 0      [6986, 13313, 48462, 59647, 91708, 97392, 1081...
# 1      [6986, 7478, 48525, 57957, 59647, 69020, 91708...
# 2      [6986, 7478, 48525, 57957, 59647, 69020, 91708...
# 3      [6986, 7478, 48525, 57957, 59647, 91708, 97392...
# 4      [6986, 7478, 48532, 57957, 59647, 69020, 91708...
# ...                                                  ...
# 21937  [6986, 6987, 48630, 59647, 69023, 91708, 97392...
# 21938  [6986, 6987, 48630, 59647, 69023, 91708, 97392...
# 21939  [6986, 6987, 48659, 52355, 59647, 71668, 91708...
# 21940  [6986, 6987, 48630, 59647, 69023, 91708, 97392...
# 21941  [6986, 8872, 48332, 59647, 69024, 91708, 97392...
#
# [21317 rows x 8 columns]

# %% [markdown]
# Save to a csv

# %%
animals_df.to_csv("animals.csv", index=False)
print("Saved animals.csv with", len(animals_df), "rows.")
# Out:
# Saved animals.csv with 21317 rows.
